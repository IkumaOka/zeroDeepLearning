# %%
using PyPlot
f(x, y) = x^2 + y^2 / 4
# Out:
# ┌ Info: Precompiling PyPlot [d330b81b-6aea-500a-939a-2ce795aea3ee]
# └ @ Base loading.jl:1342
# ┌ Info: Installing matplotlib via the Conda matplotlib package...
# └ @ PyCall /Users/ikumaoka/.julia/packages/PyCall/BD546/src/PyCall.jl:711
# ┌ Info: Running `conda install -y matplotlib` in root environment
# └ @ Conda /Users/ikumaoka/.julia/packages/Conda/sNGum/src/Conda.jl:128
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/ikumaoka/.julia/conda/3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       hb1e8313_2         398 KB
#     ca-certificates-2021.7.5   |       hecd8cb5_1         113 KB
#     certifi-2021.5.30          |   py38hecd8cb5_0         139 KB
#     conda-4.10.3               |   py38hecd8cb5_0         2.9 MB
# ...

# %%
x = LinRange(-5, 5, 300)
y = LinRange(-5, 5, 300)
# Out:
# 300-element LinRange{Float64}:
#  -5.0,-4.96656,-4.93311,-4.89967,…,4.86622,4.89967,4.93311,4.96656,5.0

# %%
z = f.(x', y)

contour(z)

# %%
z
# Out:
# 300×300 Matrix{Float64}:
#  26.25    26.2333  26.2168  26.2003  …  26.2003  26.2168  26.2333  26.25
#  25.9167  25.9     25.8834  25.867      25.867   25.8834  25.9     25.9167
#  25.5856  25.5689  25.5524  25.5359     25.5359  25.5524  25.5689  25.5856
#  25.2567  25.2401  25.2235  25.2071     25.2071  25.2235  25.2401  25.2567
#  24.9301  24.9134  24.8969  24.8804     24.8804  24.8969  24.9134  24.9301
#  24.6057  24.5891  24.5725  24.5561  …  24.5561  24.5725  24.5891  24.6057
#  24.2836  24.2669  24.2504  24.2339     24.2339  24.2504  24.2669  24.2836
#  23.9637  23.947   23.9305  23.914      23.914   23.9305  23.947   23.9637
#  23.646   23.6293  23.6128  23.5963     23.5963  23.6128  23.6293  23.646
#  23.3306  23.3139  23.2973  23.2809     23.2809  23.2973  23.3139  23.3306
#  23.0174  23.0007  22.9842  22.9677  …  22.9677  22.9842  23.0007  23.0174
#  22.7064  22.6897  22.6732  22.6568     22.6568  22.6732  22.6897  22.7064
# ...

# %%
x
# Out:
# 300-element LinRange{Float64}:
#  -5.0,-4.96656,-4.93311,-4.89967,…,4.86622,4.89967,4.93311,4.96656,5.0
