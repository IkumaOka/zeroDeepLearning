# %%
using PyPlot

# %%
x = collect(-7.5:1:7.5)
y = collect(-7.5:1:7.5)
# Out:
# 16-element Vector{Float64}:
#  -7.5
#  -6.5
#  -5.5
#  -4.5
#  -3.5
#  -2.5
#  -1.5
#  -0.5
#   0.5
#   1.5
#   2.5
#   3.5
#   4.5
#   5.5
#   6.5
#   7.5

# %%
# xGrid = repeat(x, outer=(length(y),1))
# yGrid = repeat(y',  outer=(1,length(x)))

# %%
function f(x::Float64, y::Float64)
    return x^2 / 20.0 + y^2
end
# Out:
# f (generic function with 1 method)

# %%
Z = f.(x', y)
# Out:
# 151×151 Matrix{Float64}:
#  59.0625  58.988  58.9145  58.842  …  58.842  58.9145  58.988  59.0625
#  57.5725  57.498  57.4245  57.352     57.352  57.4245  57.498  57.5725
#  56.1025  56.028  55.9545  55.882     55.882  55.9545  56.028  56.1025
#  54.6525  54.578  54.5045  54.432     54.432  54.5045  54.578  54.6525
#  53.2225  53.148  53.0745  53.002     53.002  53.0745  53.148  53.2225
#  51.8125  51.738  51.6645  51.592  …  51.592  51.6645  51.738  51.8125
#  50.4225  50.348  50.2745  50.202     50.202  50.2745  50.348  50.4225
#  49.0525  48.978  48.9045  48.832     48.832  48.9045  48.978  49.0525
#  47.7025  47.628  47.5545  47.482     47.482  47.5545  47.628  47.7025
#  46.3725  46.298  46.2245  46.152     46.152  46.2245  46.298  46.3725
#  45.0625  44.988  44.9145  44.842  …  44.842  44.9145  44.988  45.0625
#  43.7725  43.698  43.6245  43.552     43.552  43.6245  43.698  43.7725
#  42.5025  42.428  42.3545  42.282     42.282  42.3545  42.428  42.5025
# ...

# %%
# mask = Z .> 14.5
# Z[mask] .= 0

# %%
contour(Z)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7fc82d588070>

# %%
x_history = [-1 -2 1 2]
y_history = [1 2 3 4]
# Out:
# 1×4 Matrix{Int64}:
#  1  2  3  4

# %%
PyPlot.contour(Z)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.contour.QuadContourSet object at 0x7fc82d700f40>

# %%
ylim(-10, 10)
xlim(-10, 10)
plot(x, y, color="m", marker="o", markerfacecolor="r",
　　linestyle="-", label=raw"$\sin(x)$")
plot(0, 0, "+")
contour(Z)
xlabel("x")
ylabel("y")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(24.0, 0.5, 'y')

# %%
fig, axes = subplots(2, 2)
# Out:
# Figure(PyObject <Figure size 640x480 with 4 Axes>)
# (Figure(PyObject <Figure size 640x480 with 4 Axes>), PyCall.PyObject[PyObject <AxesSubplot:> PyObject <AxesSubplot:>; PyObject <AxesSubplot:> PyObject <AxesSubplot:>])

# %%
ax = axes[1, 1]
ax.plot(x, y)
# Out:
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fc82d70f1c0>

# %%
show()
